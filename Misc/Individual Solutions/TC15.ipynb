# %%
import cv2
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt
from google.colab.patches import cv2_imshow

# %%
img = cv2.imread("/content/15-beast-mode-computer-vision-(this-one-is-from-wikipedia).jpg")
print(img.shape)
cv2_imshow(img)
# Out:
# (330, 330, 3)
# <PIL.Image.Image image mode=RGB size=330x330>

# %%
# Convert the image to grayscale
gray_img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# Display the grayscale image

cv2_imshow(gray_img)
# Out:
# <PIL.Image.Image image mode=L size=330x330>

# %%
# Binarize the image using a threshold

ret, binary_img = cv2.threshold(gray_img, 88, 255, cv2.THRESH_BINARY)


# Display the binary image

cv2_imshow(binary_img)
# Out:
# <PIL.Image.Image image mode=L size=330x330>
